# %%
import os
import sys

sys.path.append(os.path.abspath(".."))

from src.loaders import list_excel_sheets, load_excel_sheet
from src.utils import RAW_SOURCE_DIRS

from src.parsers.qilt import parse_qilt_sheet, find_all_qilt_sheets

# %%
qilt_folder = "QILT"
gos_excel_file_name = "QILT-2024-GOS"

gos_excel_file = RAW_SOURCE_DIRS[qilt_folder][gos_excel_file_name]

gos_excel_sheets = list_excel_sheets(qilt_folder, gos_excel_file)
gos_excel_sheet = gos_excel_sheets[1] # ! the test one

df = load_excel_sheet(qilt_folder, gos_excel_file, gos_excel_sheet)
df
# Out:
#    Employment (FTE, OE, LF, SAL) and study outcomes among all course levels from all provider types by provider type, 2023 - 2024   \
# 0                                       Back to INDEX
# 1                                                 NaN
# 2                                                 NaN
# 3                                  Undergraduate 2023
# 4                                  Undergraduate 2023
# 5                                  Undergraduate 2023
# 6                                  Undergraduate 2024
# 7                                  Undergraduate 2024
# 8                                  Undergraduate 2024
# 9                        Postgraduate coursework 2023
# 10                       Postgraduate coursework 2023
# 11                       Postgraduate coursework 2023
# 12                       Postgraduate coursework 2024
# 13                       Postgraduate coursework 2024
# 14                       Postgraduate coursework 2024
# ...

# %%
alternative_excel_sheet = gos_excel_sheets[4] # ! an alternative example

try:
    parsed_qilt_sheet = parse_qilt_sheet(qilt_folder, gos_excel_file, alternative_excel_sheet)
except ValueError:
    print("No header found")
else:
    print(parsed_qilt_sheet.name)
    parsed_qilt_sheet.table # ! a table, but yet to be cleaned
# Out:
# EMP_PGR_ALL_2Y_AREA

# %%
gos_excel_sheets_df = find_all_qilt_sheets(qilt_folder, gos_excel_file)
gos_excel_sheets_df # ! use these results to inform what is chosen
# Out:
#                                 Sheet name  \
# Sheet number
# 1                                    INDEX
# 2               OVERALL_ALL_ALL_2Y_HEPTYPE
# 3                       EMP_UG_ALL_2Y_AREA
# 4                      EMP_PGC_ALL_2Y_AREA
# 5                      EMP_PGR_ALL_2Y_AREA
# ...                                    ...
# 155                CRSPREP_PGC_ALL_1Y_AREA
# 156                CRSPREP_PGR_ALL_1Y_AREA
# 157            CRSPREP_UG_ALL_1Y_AREA_OCCF
# 158           CRSPREP_PGC_ALL_1Y_AREA_OCCF
# 159           CRSPREP_PGR_ALL_1Y_AREA_OCCF
#
#                                                     Sheet title
# Sheet number
# 1                                   GOS 2024 Tables and Figures
# 2             Employment (FTE, OE, LF, SAL) and study outcom...
# 3             Employment outcomes (FTE, OE, LF), 2023-2024 a...
# 4             Employment outcomes (FTE, OE, LF), 2023-2024 a...
# 5             Employment outcomes (FTE, OE, LF), 2023-2024 a...
# ...

# %%
gos_l_excel_file_name = "QILT-2024-GOS-L" # ! data comparison, use ChatGPT to see what is common
gos_l_excel_file = RAW_SOURCE_DIRS[qilt_folder][gos_l_excel_file_name]
gos_l_excel_sheets_df = find_all_qilt_sheets(qilt_folder, gos_l_excel_file)
gos_l_excel_sheets_df
# Out:
#                           Sheet name  \
# Sheet number
# 1                              INDEX
# 2                      FTE_UG_ALL_5Y
# 3                FTE_ALL_ALL_1Y_AREA
# 4                     STMT_UG_ALL_3Y
# 5                    STMT_PGC_ALL_3Y
# ...                              ...
# 158               STMT_PGR_ALL_1Y_SG
# 159              STMT_UG_ALL_1Y_E315
# 160           STMT_UG_ALL_1Y_HEPTYPE
# 161                STMT_UG_ALL_1Y_SG
# 162             SPOQ_ALL_ALL_1Y_E942
#
#                                                     Sheet title
# Sheet number
# 1                                 GOS-L 2024 Tables and Figures
# 2             Short-term and medium-term domestic full-time ...
# 3             Short-term and medium-term full-time domestic ...
# 4             Short-term and medium-term domestic employment...
# 5             Short-term and medium-term domestic employment...
# ...                                                         ...
# ...
