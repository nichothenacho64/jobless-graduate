# %%
import os
import sys

sys.path.append(os.path.abspath(".."))

from src.loaders import initialise_abs_sheet
from src.preparation.abs import prepare_abs_sheet

# %%
abs_sheet_1 = initialise_abs_sheet(1)

abs_sheet_1_sheet = prepare_abs_sheet(abs_sheet_1.folder, abs_sheet_1.file_name, abs_sheet_1.sheet_name)
abs_sheet_1_sheet.title
# Out:
# 'Current study, by selected characteristics and state/territory, Persons aged 15–74 years(a)'
